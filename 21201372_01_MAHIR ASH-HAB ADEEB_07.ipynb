# %%
#task_1
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]

for i in range(len(my_list)-1):
  for j in range(len(my_list)-1):
    if (my_list[j]>my_list[j+1]):
      my_list[j], my_list[j+1] = my_list[j+1], my_list[j]
      
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#task_2
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]

for i in range(len(my_list)-1):
  min_val = my_list[i]
  min_index = i

  for j in range(i+1,len(my_list)):
    if my_list[j] < my_list[min_index]:
      min_val = my_list[j]
      min_index = j
  my_list[i], my_list[min_index] = my_list[min_index], my_list[i]
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#task_3
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]

for i in range(len(my_list)-1):
  for j in range(len(my_list)-1):
    if (my_list[j]<my_list[j+1]):
      my_list[j], my_list[j+1] = my_list[j+1], my_list[j]
      
print(my_list)
# Out:
# [29, 20, 18, 17, 15, 14, 12, 11, 10, 6, 5, 3, 2, 2, 1]

# %%
#task_4
sitting_list = [10,30,20,70,11,15,22,16,58,100,12,56,70,80]

for i in range(0,len(sitting_list),2):
  for j in range(0,len(sitting_list)-2,2):
    if (sitting_list[j]>sitting_list[j+2]):
      sitting_list[j], sitting_list[j+2] = sitting_list[j+2], sitting_list[j]

for i in range(1,len(sitting_list),2):
  for j in range(1,len(sitting_list)-2,2):
    if sitting_list[j]<sitting_list[j+2]:
      sitting_list[j], sitting_list[j+2] = sitting_list[j+2], sitting_list[j]
      
print(sitting_list)
# Out:
# [10, 100, 11, 80, 12, 70, 20, 56, 22, 30, 58, 16, 70, 15]

# %%
#taks_5
def sort_names(lsts, course):

  name = []
  marks = []

  if (course == "CSE110"):
    for i in range(len(lsts)):
      name.append(lsts[i][0])
      marks.append(lsts[i][1])

  if (course == "PHY111"):
    for i in range(len(lsts)):
      name.append(lsts[i][0])
      marks.append(lsts[i][2])

  if (course == "MAT110"):
    for i in range(len(lsts)):
      name.append(lsts[i][0])
      marks.append(lsts[i][3])
  
  for i in range(len(marks)):
    for j in range(0,len(marks)-1):
      if (marks[j] < marks[j+1]):
        marks[j], marks[j+1] = marks[j+1], marks[j]
        name[j], name[j+1] = name[j+1], name[j]
  for k in name:
    print(k)
  
lst = [ ["Alan", 95, 87, 91], ["Turing", 92, 90, 83], ["Elon", 87, 92, 80], ["Musk", 85, 94, 90] ]
cors = input()
sort_names(lst,cors)
# Out:
# MAT110
# Alan
# Musk
# Turing
# Elon

# %%
#task_6
my_list = [4, 2, 3, 1, 6, 5]
my_list2 = my_list.copy()
for i in range(len(my_list)-1):
  for j in range(len(my_list)-1):
    if (my_list[j]>my_list[j+1]):
      my_list[j], my_list[j+1] = my_list[j+1], my_list[j]
      
count = 0
for i in range(len(my_list)):
  if my_list[i] != my_list2[i]:
    count += 1
print(count)
# Out:
# 4

# %%
#task_7
new_list=[]
for i in range(1,9):
  num=int(input())
  new_list.append(num)
  new_list.sort()
print("Sorted list =", new_list)

if (len(new_list)%2 == 0):
  a = new_list[len(new_list)//2-1]
  b = new_list[len(new_list)//2]
  median = (a+b)/2
  print(median)
else:
  median = new_list[len(new_list)//2]
  print(median)
# Out:
# 1
# 7
# 9
# 10
# 2
# 7
# 6
# 5
# Sorted list = [1, 2, 5, 6, 7, 7, 9, 10]
# 6.5

# %%
#task_8
list_one = input().split(',')
for i in range(len(list_one)):
  list_one[i] = int(list_one[i])
for i in range(len(list_one)-1):
  for j in range(len(list_one)-i-1):
    if list_one[j] > list_one[j+1]:
      a = list_one[j]
      list_one[j] = list_one[j+1]
      list_one[j+1] = a
neg_list = []
pos_list = []
for i in list_one:
  if i<0:
    neg_list.append(i)
  else:
    pos_list.append(i)
print(f"Two pairs which have the smallest sum = {pos_list[1]} and {neg_list[-1]}")
# Out:
# -10,15,2,4,-4,7,-8
# Two pairs which have the smallest sum = 4 and -4

# %%
#task_9
def distance(tup):
    dist = ((tup[0]) ** 2 + (tup[1]) ** 2) ** (1 / 2)
    return dist


def min_dist(given_list):
    for i in range(len(given_list)):
        for j in range(len(given_list) - i - 1):
            if distance(given_list[j]) > distance(given_list[j + 1]):
                given_list[j], given_list[j + 1] = given_list[j + 1], given_list[j]

    return f"Minimum distance = {distance(given_list[0])} Here the closest point is {given_list[0]}" \
           f" which has a distance of {distance(given_list[0])} from the origin."



points = [(5, 3), (2, 9), (-2, 7), (-3, -4), (0, 6), (7, -2)]  
print(min_dist(points))
# Out:
# Minimum distance = 5.0 Here the closest point is (-3, -4) which has a distance of 5.0 from the origin.
